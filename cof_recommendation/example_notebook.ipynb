# %%
from recommendation import *

# %%
# batch G1
POINTS = [
    ('ald_1', 'amine_11'),
    ('ald_7', 'amine_11'),
    ('ald_8', 'amine_12'),
    ('ald_20', 'amine_11'),
    ('ald_13', 'amine_8')
]
EVALUATIONS = [0, 0, 0, 0, 1]

cofr = CofRecommendation()
for i in range(len(POINTS)):
    cofr.register(POINTS[i], EVALUATIONS[i])

# batch G2 & G3
POINTS = [
    ('ald_13', 'amine_11'),
    ('ald_13', 'amine_12'),
    ('ald_13', 'amine_10'),
    ('ald_25', 'amine_12'),
    ('ald_25', 'amine_10'),
    ('ald_23', 'amine_12')
]
EVALUATIONS = [2, 2, 1, 2, 0, 2]

for i in range(len(POINTS)):
    cofr.register(POINTS[i], EVALUATIONS[i])

# evaluating G4 batch
batch = [
    ('ald_11', 'amine_11'),
    ('ald_8', 'amine_11'),
    ('ald_8', 'amine_17'),
    ('ald_10', 'amine_11'),
    ('ald_21', 'amine_11'),
    ('ald_13', 'amine_15'),
    ('ald_24', 'amine_11'),
    ('ald_25', 'amine_11'),
    ('ald_25', 'amine_17'),
    ('ald_25', 'amine_8'),
    ('ald_23', 'amine_11'),
]
# Out:
# C:\Users\darkn\PycharmProjects\Fluorocofs\cof_recommendation\siamese_model.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.pretrain_net.load_state_dict(torch.load(name))

# %%
cofr.evaluate_batch(batch)
# Out:
# C:\Users\darkn\PycharmProjects\Fluorocofs\cof_recommendation\trainer.py:40: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   return torch.Tensor(x1), torch.Tensor(x2), torch.Tensor(target)
# Epoch: 1/20. Train set: Loss: 0.3439
# Epoch: 2/20. Train set: Loss: 0.3429
# Epoch: 3/20. Train set: Loss: 0.3417
# Epoch: 4/20. Train set: Loss: 0.3402
# Epoch: 5/20. Train set: Loss: 0.3386
# Epoch: 6/20. Train set: Loss: 0.3367
# Epoch: 7/20. Train set: Loss: 0.3345
# Epoch: 8/20. Train set: Loss: 0.3320
# Epoch: 9/20. Train set: Loss: 0.3291
# Epoch: 10/20. Train set: Loss: 0.3288
# Epoch: 11/20. Train set: Loss: 0.3284
# Epoch: 12/20. Train set: Loss: 0.3281
# Epoch: 13/20. Train set: Loss: 0.3277
# Epoch: 14/20. Train set: Loss: 0.3274
# Epoch: 15/20. Train set: Loss: 0.3270
# Epoch: 16/20. Train set: Loss: 0.3266
# Epoch: 17/20. Train set: Loss: 0.3262
# Epoch: 18/20. Train set: Loss: 0.3262
# Epoch: 19/20. Train set: Loss: 0.3261
# Epoch: 20/20. Train set: Loss: 0.3261
# Pair ('ald_11', 'amine_11') predicted score (rounded): 0
# Pair ('ald_8', 'amine_11') predicted score (rounded): 0
# Pair ('ald_8', 'amine_17') predicted score (rounded): 0
# Pair ('ald_10', 'amine_11') predicted score (rounded): 1
# Pair ('ald_21', 'amine_11') predicted score (rounded): 2
# Pair ('ald_13', 'amine_15') predicted score (rounded): 0
# Pair ('ald_24', 'amine_11') predicted score (rounded): 2
# Pair ('ald_25', 'amine_11') predicted score (rounded): 0
# Pair ('ald_25', 'amine_17') predicted score (rounded): 0
# Pair ('ald_25', 'amine_8') predicted score (rounded): 0
# Pair ('ald_23', 'amine_11') predicted score (rounded): 2
# All results saved to evaluate_results.xlsx (rows=amines, cols=alds)
